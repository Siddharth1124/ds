# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('dataset_Facebook.csv' , sep=";")
data
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
data.isnull().sum()
# Out:
# Page total likes                                                       0
# Type                                                                   0
# Category                                                               0
# Post Month                                                             0
# Post Weekday                                                           0
# Post Hour                                                              0
# Paid                                                                   1
# Lifetime Post Total Reach                                              0
# Lifetime Post Total Impressions                                        0
# Lifetime Engaged Users                                                 0
# Lifetime Post Consumers                                                0
# Lifetime Post Consumptions                                             0
# Lifetime Post Impressions by people who have liked your Page           0
# ...

# %%
num_cols = data.select_dtypes(include='number')
means = num_cols.mean()
data = data.fillna(means)
data
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
slice_sub = data.iloc[:175, :]
slice_sub
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 170            135195   Photo         3           9             2          9
# 171            135195   Photo         1           9             2          2
# 172            135195  Status         2           9             1         10
# 173            135195   Photo         1           9             1          4
# 174            135195   Photo         2           9             7          3
#
# ...

# %%
loc_sub = data[data["Type"]=="Status"]
loc_sub
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 1              139441  Status         2          12             3         10
# 5              139441  Status         2          12             1          9
# 8              139441  Status         2          12             7          3
# 10             139441  Status         2          12             5         10
# 15             138414  Status         2          12             3         10
# 18             138414  Status         3          12             2          3
# 24             138414  Status         2          12             6         10
# 25             138458  Status         2          12             6          3
# 26             138458  Status         2          12             5         11
# 38             138895  Status         2          12             7          9
# 40             138895  Status         2          12             6         11
# ...

# %%
con_sub = data[data["Lifetime Engaged Users"] > 1000]
con_sub
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 1              139441  Status         2          12             3         10
# 3              139441   Photo         2          12             2         10
# 5              139441  Status         2          12             1          9
# 8              139441  Status         2          12             7          3
# 10             139441  Status         2          12             5         10
# ..                ...     ...       ...         ...           ...        ...
# 483             86491   Photo         2           1             3          3
# 484             86491   Photo         3           1             2          7
# 486             85979   Photo         3           1             1         12
# 488             85979   Photo         3           1             7         10
# 493             85093   Photo         3           1             1          2
#
# ...

# %%
con_sub2 = data[(data["Lifetime Engaged Users"]==608) | (data["Lifetime Post Consumers"]==512)]
con_sub2
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 248            129600  Photo         3           7             1          6
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 248   0.0                       3406                             5656
#
#      Lifetime Engaged Users  Lifetime Post Consumers  \
# 248                     571                      512
#
#      Lifetime Post Consumptions  \
# 248                         731
#
#      Lifetime Post Impressions by people who have liked your Page  \
# 248                                               4446
#
#      Lifetime Post reach by people who like your Page  \
# 248                                              2598
#
#      Lifetime People who have liked your Page and engaged with your post  \
# 248                                                355
#
#      comment  like  share  Total Interactions
# 248        1  98.0   19.0                 118

# %%
con_sub3 = data[data["Post Hour"]> 7]
con_sub3
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 1              139441  Status         2          12             3         10
# 3              139441   Photo         2          12             2         10
# 5              139441  Status         2          12             1          9
# 7              139441   Photo         3          12             7          9
# 9              139441   Photo         3          12             6         10
# ..                ...     ...       ...         ...           ...        ...
# 490             85979   Photo         3           1             6         11
# 492             85979    Link         1           1             5         11
# 494             85093   Photo         3           1             7         10
# 496             81370   Photo         2           1             5          8
# 498             81370   Photo         3           1             4         11
#
# ...

# %%
slice_sub2 = data.iloc[:7,:]
slice_sub2
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
# 5            139441  Status         2          12             1          9
# 6            139441   Photo         3          12             1          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# ...

# %%
col_sub = data[["Post Hour", "comment", "like", "share", "Total Interactions"]]
col_sub
# Out:
#      Post Hour  comment    like  share  Total Interactions
# 0            3        4    79.0   17.0                 100
# 1           10        5   130.0   29.0                 164
# 2            3        0    66.0   14.0                  80
# 3           10       58  1572.0  147.0                1777
# 4            3       19   325.0   49.0                 393
# ..         ...      ...     ...    ...                 ...
# 495          2        5    53.0   26.0                  84
# 496          8        0    53.0   22.0                  75
# 497          2        4    93.0   18.0                 115
# 498         11        7    91.0   38.0                 136
# 499          4        0    91.0   28.0                 119
#
# [500 rows x 5 columns]

# %%
row_merge = pd.concat([slice_sub, con_sub2], axis=0)
row_merge
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 171            135195   Photo         1           9             2          2
# 172            135195  Status         2           9             1         10
# 173            135195   Photo         1           9             1          4
# 174            135195   Photo         2           9             7          3
# 248            129600   Photo         3           7             1          6
#
# ...

# %%
col_merge = slice_sub.merge(col_sub, how="left", on=["Post Hour", "comment", "like", "share", "Total Interactions"])
col_merge
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 172            135195   Photo         3           9             2          9
# 173            135195   Photo         1           9             2          2
# 174            135195  Status         2           9             1         10
# 175            135195   Photo         1           9             1          4
# 176            135195   Photo         2           9             7          3
#
# ...

# %%
data.sort_values(by='Post Hour')
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 333            119198  Photo         3           5             2          1
# 258            129600  Photo         2           7             3          1
# 212            132201  Photo         2           8             5          1
# 154            135713  Photo         2          10             4          1
# 75             137893  Photo         1          11             3          2
# ..                ...    ...       ...         ...           ...        ...
# 423            102112  Photo         1           3             1         18
# 422            102112  Photo         1           3             1         19
# 381            109670  Photo         3           4             6         20
# 287            126141  Photo         1           6             4         22
# 230            131630  Photo         3           7             2         23
#
# ...

# %%
data.sort_values('Post Hour' , ascending=False)
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 230            131630  Photo         3           7             2         23
# 287            126141  Photo         1           6             4         22
# 381            109670  Photo         3           4             6         20
# 422            102112  Photo         1           3             1         19
# 426            100732  Photo         1           3             7         18
# ..                ...    ...       ...         ...           ...        ...
# 178            135195  Photo         2           9             5          2
# 333            119198  Photo         3           5             2          1
# 258            129600  Photo         2           7             3          1
# 154            135713  Photo         2          10             4          1
# 212            132201  Photo         2           8             5          1
#
# ...

# %%
tran_data = data.T
tran_data
# Out:
#                                                        0       1       2    \
# Page total likes                                    139441  139441  139441
# Type                                                 Photo  Status   Photo
# Category                                                 2       2       3
# Post Month                                              12      12      12
# Post Weekday                                             4       3       3
# Post Hour                                                3      10       3
# Paid                                                   0.0     0.0     0.0
# Lifetime Post Total Reach                             2752   10460    2413
# Lifetime Post Total Impressions                       5091   19057    4373
# Lifetime Engaged Users                                 178    1457     177
# Lifetime Post Consumers                                109    1361     113
# ...

# %%
data.shape
# Out:
# (500, 19)

# %%
pivot_df = data.pivot_table(values="like", index="Category", columns="Type", aggfunc="max")
pivot_df
# Out:
# Type       Link   Photo  Status  Video
# Category
# 1         379.0  1622.0   210.0  449.0
# 2          32.0  5172.0   859.0    NaN
# 3          68.0  1998.0   227.0    NaN

# %%
pivot_df.columns
# Out:
# Index(['Link', 'Photo', 'Status', 'Video'], dtype='object', name='Type')

# %%
pivot_df.reset_index().columns
# Out:
# Index(['Category', 'Link', 'Photo', 'Status', 'Video'], dtype='object', name='Type')

# %%
reshaped_df = pivot_df.reset_index().melt(id_vars="Category", var_name="Type", value_name="like")
reshaped_df
# Out:
#     Category    Type    like
# 0          1    Link   379.0
# 1          2    Link    32.0
# 2          3    Link    68.0
# 3          1   Photo  1622.0
# 4          2   Photo  5172.0
# 5          3   Photo  1998.0
# 6          1  Status   210.0
# 7          2  Status   859.0
# 8          3  Status   227.0
# 9          1   Video   449.0
# 10         2   Video     NaN
# 11         3   Video     NaN

# %%
reshaped_df.T
# Out:
#              0     1     2       3       4       5       6       7       8   \
# Category      1     2     3       1       2       3       1       2       3
# Type       Link  Link  Link   Photo   Photo   Photo  Status  Status  Status
# like      379.0  32.0  68.0  1622.0  5172.0  1998.0   210.0   859.0   227.0
#
#              9      10     11
# Category      1      2      3
# Type      Video  Video  Video
# like      449.0    NaN    NaN

# %%
sns.pairplot(data.iloc[:, 5:15])

# %%
sns.heatmap(data.iloc[:, 5:15].corr(), annot=True)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='Post Month', data=data, palette='viridis')
plt.title("Category Distribution")
plt.show()
# Out:
# C:\Users\gpraj\AppData\Local\Temp\ipykernel_2476\3226848253.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Post Month', data=data, palette='viridis')
